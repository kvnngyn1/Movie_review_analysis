# %% [markdown]
# # Top Earners in Movie Industry
#
# ## Table of Contents
#
# <ul>
#     <li><a href="#intro">Introduction</a></li>
#     <li><a href="#eda">Exploratory Data Analysis</a></li>
#     <li><a href="#conclusion">Conclusion</a></li>
# </ul>

# %% [markdown]
# <a id="#intro"></a>
# ## Introduction
#
# > This analysis project is to be done using the imdb movie data. When the analysis is completed, you should be able to find the top 5 highest grossing directors, the top 5 highest grossing movie genres of all time, comparing the revenue of the highest grossing movies and which companies released the most movies.
#
# > There are 10 columns that will not be needed for the analysis. Use pandas to drop these columns. HINT: Only the columns pertaining to revenue will be needed.
#
# > To get you started, I've already placed the needed code for getting the packages and datafile that you will be using for the project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imdb-movies.csv')

# %% [markdown]
# ### Drop columns without neccesary information and remove all records with no financial information -- Pay close attention to things that don't tell you anything regarding financial data

# %%
df.head(10)
df.count()
# Out:
# id                      10866
# imdb_id                 10856
# popularity              10866
# budget                  10866
# revenue                 10866
# original_title          10866
# cast                    10790
# homepage                 2936
# director                10822
# tagline                  8042
# keywords                 9373
# overview                10862
# runtime                 10866
# genres                  10843
# production_companies     9836
# release_date            10866
# vote_count              10866
# vote_average            10866
# release_year            10866
# budget_adj              10866
# revenue_adj             10866
# dtype: int64

# %%
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
# display all columns and decide what is needed and what is not needed
# find top 5 highests grossing directors
# top 5 grossing movie genres of all time
# compare revenue of the highest grossing movies
# which companies released the most movies?

df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
# Do this once. run it a second time there will be an error message.
# To answer the questions all we need are the movie titles, director, genres, production companies, budget, and revenue
df=df.drop(['id', 'imdb_id','keywords','cast','homepage','overview','vote_count', 'vote_average','tagline', 'runtime','budget_adj',
       'revenue_adj' ],axis=1)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
# display first 15
df[df.isna().any(axis=1)].head(15)
# Out:
#      popularity   budget  revenue               original_title  \
# 228    0.584363        0        0            Racing Extinction
# 259    0.476341        0        0          Crown for Christmas
# 295    0.417191        0        0        12 Gifts of Christmas
# 298    0.370258        0        0  The Girl in the Photographs
# 328    0.367617        0        0                 Advantageous
# 370    0.314199        0  2334228                         Meru
# 374    0.302474        0        0      The Sisterhood of Night
# 382    0.295946        0        0                   Unexpected
# 388    0.289526   700000        0                       Walter
# 393    0.283194  2000000        0      Night Of The Living Deb
# 401    0.270842        0        0                   Night Owls
# 404    0.264997        0        0          Ten Thousand Saints
# 410    0.097514        0        0               Anarchy Parlor
# 414    0.250866        0        0                 Those People
# 415    0.249595        0        0               Show Me a Hero
#
#                                  director                        genres  \
# 228                        Louie Psihoyos         Adventure|Documentary
# 259                             Alex Zamm                      TV Movie
# 295                        Peter Sullivan               Family|TV Movie
# 298                            Nick Simon         Crime|Horror|Thriller
# 328                        Jennifer Phang  Science Fiction|Drama|Family
# 370  Jimmy Chin|Elizabeth Chai Vasarhelyi         Adventure|Documentary
# 374                        Caryn Waechter        Mystery|Drama|Thriller
# 382                         Kris Swanberg                  Drama|Comedy
# 388                           Anna Mastro                  Drama|Comedy
# 393                           Kyle Rankin                 Comedy|Horror
# 401                          Charles Hood                  Drama|Comedy
# 404  Robert Pulcini|Shari Springer Berman            Music|Comedy|Drama
# 410                Kenny Gage|Devon Downs                        Horror
# 414                             Joey Kuhn                 Romance|Drama
# 415                           Paul Haggis           History|Crime|Drama
#
#     production_companies release_date  release_year
# 228                  NaN      1/24/15          2015
# 259                  NaN     11/27/15          2015
# 295                  NaN     11/26/15          2015
# 298                  NaN      9/14/15          2015
# 328                  NaN      6/23/15          2015
# 370                  NaN      1/25/15          2015
# 374                  NaN      4/10/15          2015
# 382                  NaN      7/24/15          2015
# 388                  NaN      3/13/15          2015
# 393                  NaN      8/29/15          2015
# 401                  NaN      3/15/15          2015
# 404                  NaN      8/14/15          2015
# 410                  NaN       1/1/15          2015
# 414                  NaN      5/16/15          2015
# 415                  NaN      8/16/15          2015

# %%
df.isna().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# director                  44
# genres                    23
# production_companies    1030
# release_date               0
# release_year               0
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
# Delete all records with null, or empty values
df.dropna(inplace=True)
df.isna().sum()
# Out:
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# director                0
# genres                  0
# production_companies    0
# release_date            0
# release_year            0
# dtype: int64

# %%
# display cleaned data. in this case i displayed FIRST 10
df.head(10)
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
# 5    9.110700  135000000   532950503                  The Revenant
# 6    8.654359  155000000   440603537            Terminator Genisys
# 7    7.667400  108000000   595380321                   The Martian
# 8    7.404165   74000000  1156730962                       Minions
# 9    6.326804  175000000   853708609                    Inside Out
#
#                          director                                     genres  \
# 0                 Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 1                   George Miller  Action|Adventure|Science Fiction|Thriller
# 2                Robert Schwentke         Adventure|Science Fiction|Thriller
# 3                     J.J. Abrams   Action|Adventure|Science Fiction|Fantasy
# 4                       James Wan                      Action|Crime|Thriller
# 5  Alejandro GonzÃ¡lez IÃ±Ã¡rritu           Western|Drama|Adventure|Thriller
# 6                     Alan Taylor  Science Fiction|Action|Thriller|Adventure
# 7                    Ridley Scott            Drama|Adventure|Science Fiction
# 8        Kyle Balda|Pierre Coffin          Family|Animation|Adventure|Comedy
# 9                     Pete Docter                    Comedy|Animation|Family
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15
# 5  Regency Enterprises|Appian Way|CatchPlay|Anony...     12/25/15
# 6            Paramount Pictures|Skydance Productions      6/23/15
# 7  Twentieth Century Fox Film Corporation|Scott F...      9/30/15
# 8      Universal Pictures|Illumination Entertainment      6/17/15
# 9  Walt Disney Pictures|Pixar Animation Studios|W...       6/9/15
#
#    release_year
# 0          2015
# 1          2015
# 2          2015
# 3          2015
# 4          2015
# 5          2015
# 6          2015
# 7          2015
# 8          2015
# 9          2015

# %% [markdown]
# #### Here's a helpful hint from my own analysis when I ran this the first time. This may help shed light on what your data set should look like.
#
# #### If I created one record for each the `production_companies` a movie was release under and one record each for `genres`<br>and tried to run calculations, it wouldn't work because for many records, the amount of `production_companies`<br>and `genres` aren't the same, so I'll create 2 dataframes; one w/o a `production_companies` column and one w/o a `genres` columns

# %%
# CREATE TWO DATAFRAMES
# One without genres
# one without poroduction companies

# %%
# genre dataframe without production_companies column
genre_df = df.drop(['production_companies'],axis=1)
genre_df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                  director                                     genres  \
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 1           George Miller  Action|Adventure|Science Fiction|Thriller
# 2        Robert Schwentke         Adventure|Science Fiction|Thriller
# 3             J.J. Abrams   Action|Adventure|Science Fiction|Fantasy
# 4               James Wan                      Action|Crime|Thriller
# ...                   ...                                        ...
# 10861         Bruce Brown                                Documentary
# 10862  John Frankenheimer                     Action|Adventure|Drama
# 10863      Eldar Ryazanov                             Mystery|Comedy
# 10864         Woody Allen                              Action|Comedy
# 10865    Harold P. Warren                                     Horror
#
#       release_date  release_year
# 0           6/9/15          2015
# 1          5/13/15          2015
# 2          3/18/15          2015
# 3         12/15/15          2015
# 4           4/1/15          2015
# ...            ...           ...
# 10861      6/15/66          1966
# 10862     12/21/66          1966
# 10863       1/1/66          1966
# 10864      11/2/66          1966
# 10865     11/15/66          1966
#
# [9807 rows x 8 columns]

# %%
# production dataframe without genre column
production_df=df.drop(['genres'],axis=1)
production_df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                  director                               production_companies  \
# 0         Colin Trevorrow  Universal Studios|Amblin Entertainment|Legenda...
# 1           George Miller  Village Roadshow Pictures|Kennedy Miller Produ...
# 2        Robert Schwentke  Summit Entertainment|Mandeville Films|Red Wago...
# 3             J.J. Abrams          Lucasfilm|Truenorth Productions|Bad Robot
# 4               James Wan  Universal Pictures|Original Film|Media Rights ...
# ...                   ...                                                ...
# 10861         Bruce Brown                                  Bruce Brown Films
# 10862  John Frankenheimer  Cherokee Productions|Joel Productions|Douglas ...
# 10863      Eldar Ryazanov                                            Mosfilm
# 10864         Woody Allen                            Benedict Pictures Corp.
# 10865    Harold P. Warren                                          Norm-Iris
#
#       release_date  release_year
# 0           6/9/15          2015
# 1          5/13/15          2015
# 2          3/18/15          2015
# 3         12/15/15          2015
# 4           4/1/15          2015
# ...            ...           ...
# 10861      6/15/66          1966
# 10862     12/21/66          1966
# 10863       1/1/66          1966
# 10864      11/2/66          1966
# 10865     11/15/66          1966
#
# [9807 rows x 8 columns]

# %%
# function is used to reorganize and display all rows of the data
def splitDataFrame(df,target_column,separator):
    def splitToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df

# %%
genre_df=splitDataFrame(genre_df,'genres','|')
genre_df
# Out:
#        popularity     budget     revenue            original_title  \
# 0       32.985763  150000000  1513528810            Jurassic World
# 1       32.985763  150000000  1513528810            Jurassic World
# 2       32.985763  150000000  1513528810            Jurassic World
# 3       32.985763  150000000  1513528810            Jurassic World
# 4       28.419936  150000000   378436354        Mad Max: Fury Road
# ...           ...        ...         ...                       ...
# 24712    0.065141          0           0       Beregis Avtomobilya
# 24713    0.065141          0           0       Beregis Avtomobilya
# 24714    0.064317          0           0    What's Up, Tiger Lily?
# 24715    0.064317          0           0    What's Up, Tiger Lily?
# 24716    0.035919      19000           0  Manos: The Hands of Fate
#
#                director           genres release_date  release_year
# 0       Colin Trevorrow           Action       6/9/15          2015
# 1       Colin Trevorrow        Adventure       6/9/15          2015
# 2       Colin Trevorrow  Science Fiction       6/9/15          2015
# 3       Colin Trevorrow         Thriller       6/9/15          2015
# 4         George Miller           Action      5/13/15          2015
# ...                 ...              ...          ...           ...
# 24712    Eldar Ryazanov          Mystery       1/1/66          1966
# 24713    Eldar Ryazanov           Comedy       1/1/66          1966
# 24714       Woody Allen           Action      11/2/66          1966
# 24715       Woody Allen           Comedy      11/2/66          1966
# 24716  Harold P. Warren           Horror     11/15/66          1966
#
# [24717 rows x 8 columns]

# %%
production_df=splitDataFrame(production_df,'production_companies','|')
production_df
# Out:
#        popularity     budget     revenue            original_title  \
# 0       32.985763  150000000  1513528810            Jurassic World
# 1       32.985763  150000000  1513528810            Jurassic World
# 2       32.985763  150000000  1513528810            Jurassic World
# 3       32.985763  150000000  1513528810            Jurassic World
# 4       32.985763  150000000  1513528810            Jurassic World
# ...           ...        ...         ...                       ...
# 23189    0.065543          0           0                Grand Prix
# 23190    0.065543          0           0                Grand Prix
# 23191    0.065141          0           0       Beregis Avtomobilya
# 23192    0.064317          0           0    What's Up, Tiger Lily?
# 23193    0.035919      19000           0  Manos: The Hands of Fate
#
#                  director         production_companies release_date  \
# 0         Colin Trevorrow            Universal Studios       6/9/15
# 1         Colin Trevorrow         Amblin Entertainment       6/9/15
# 2         Colin Trevorrow           Legendary Pictures       6/9/15
# 3         Colin Trevorrow      Fuji Television Network       6/9/15
# 4         Colin Trevorrow                       Dentsu       6/9/15
# ...                   ...                          ...          ...
# 23189  John Frankenheimer             Joel Productions     12/21/66
# 23190  John Frankenheimer  Douglas & Lewis Productions     12/21/66
# 23191      Eldar Ryazanov                      Mosfilm       1/1/66
# 23192         Woody Allen      Benedict Pictures Corp.      11/2/66
# 23193    Harold P. Warren                    Norm-Iris     11/15/66
#
#        release_year
# 0              2015
# 1              2015
# 2              2015
# 3              2015
# 4              2015
# ...             ...
# 23189          1966
# 23190          1966
# 23191          1966
# 23192          1966
# 23193          1966
#
# [23194 rows x 8 columns]

# %% [markdown]
# <a id="eda"></a>
# ## Exploratory Data Analysis
#
# > Use Matplotlib to display your data analysis

# %%
# which companies released the most movies?
# top 5 grossing movie genres of all time
# find top 5 highests grossing directors
# compare revenue of the highest grossing movies

# %% [markdown]
# ### Which production companies released the most movies in the last 10 years? Display the top 5 production companies.

# %%
# assigned year to movies released in the last 10 years from today
year=production_df.loc[production_df['release_year'] > 2011]

# %%
# display top 5 companies with the most movies
year['production_companies'].value_counts().nlargest(5)
# Out:
# Universal Pictures       51
# Warner Bros.             46
# Paramount Pictures       35
# Columbia Pictures        35
# Blumhouse Productions    33
# Name: production_companies, dtype: int64

# %% [markdown]
# ### What 5 movie genres grossed the highest all-time?

# %%
genre_df.groupby("genres").revenue.sum().nlargest(5)
# Out:
# genres
# Action       173418313979
# Adventure    166317625752
# Comedy       142141376544
# Drama        138896772395
# Thriller     121189561087
# Name: revenue, dtype: int64

# %%
genre_df['profit'] = genre_df.revenue - genre_df.budget
print("Profit")
genre_df.groupby("genres").profit.sum().nlargest(5)
# Out:
# Profit
# genres
# Adventure    111216306097
# Action       107540425634
# Comedy        91947521248
# Drama         82656036667
# Thriller      71402548810
# Name: profit, dtype: int64

# %% [markdown]
# ### Who are the top 5 grossing directors?

# %%
df.groupby(["director"]).revenue.sum().nlargest(5)
# Out:
# director
# Steven Spielberg     9018563772
# Peter Jackson        6523244659
# James Cameron        5841894863
# Michael Bay          4917208171
# Christopher Nolan    4167548502
# Name: revenue, dtype: int64

# %%
df['profit'] = df.revenue - df.budget
print("Profit")
df.groupby("director").profit.sum().nlargest(5)
# Out:
# Profit
# director
# Steven Spielberg    7428613772
# Peter Jackson       5196468949
# James Cameron       5081849077
# Michael Bay         3557208171
# David Yates         3379295625
# Name: profit, dtype: int64

# %% [markdown]
# ### Compare the revenue of the highest grossing movies of all time.

# %%
# display total revenue from revenue column
print("Revenue")
df.groupby("original_title").revenue.sum().nlargest(5)
# Out:
# Revenue
# original_title
# Avatar                          2781505847
# Star Wars: The Force Awakens    2068178225
# Titanic                         1845034188
# The Avengers                    1568080742
# Jurassic World                  1513528810
# Name: revenue, dtype: int64

# %%
# display profit subtracting cost to make the movie
df['profit'] = df.revenue - df.budget
print("Profit")
df.groupby("original_title").profit.sum().nlargest(5)
# Out:
# Profit
# original_title
# Avatar                          2544505847
# Star Wars: The Force Awakens    1868178225
# Titanic                         1632034188
# Jurassic World                  1363528810
# Furious 7                       1316249360
# Name: profit, dtype: int64

# %% [markdown]
# <a id="conclusions"></a>
# ## Conclusions
#
# > Using the cell below, write a brief conclusion of what you have found from the anaylsis of the data. The Cell below will allow you to write plan text instead of code.

# %% [markdown]
# - Universal created the most movies in the last 10 years according to this dataset
# - Paramount and Columbia tied for thirds place for the amount of movies released in the last 10 years
# - Action makes the most gross revenue, but adventure makes the most profit overall factoring in budget
# - Steven Spielberg makes the most gross revenue and profit compared to the other directors
# - Avatar is the highest grossing movie of all time!
# - when comparing gross revenue and profit of the highest grossing movies of all time
# - Jurassic World tops The Avengers and the 5th place is taken over by Furious 7
